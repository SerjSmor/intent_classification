# %%
import transformers
import pandas as pd
from datasets import load_dataset

from app.model import IntentClassifier
from app.atis.utils import ATIS_INTENT_MAPPING as intent_mapping

dataset = load_dataset("tuetschek/atis")

# %%
from transformers import pipeline
# Bart-Large-MNLI 407M parameters, almost double of Flan-T5-Base
classifier = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli", device="cuda")

# %% [markdown]
# ## Bart Example

# %%
sequence_to_classify = "one day I will see the world"
candidate_labels = ['travel', 'cooking', 'dancing']
classifier(sequence_to_classify, candidate_labels)
#{'labels': ['travel', 'dancing', 'cooking'],
# 'scores': [0.9938651323318481, 0.0032737774308770895, 0.002861034357920289],
# 'sequence': 'one day I will see the world'}
# Out:
# {'sequence': 'one day I will see the world',
#  'labels': ['travel', 'dancing', 'cooking'],
#  'scores': [0.9938650727272034, 0.003273802110925317, 0.002861041808500886]}

# %%
dataset["train"][0]["text"], dataset["train"][0]["intent"], intent_mapping[dataset["train"][0]["intent"]]
# Out:
# ('i want to fly from boston at 838 am and arrive in denver at 1110 in the morning',
#  'flight',
#  'Flight Booking Request')

# %%
# use the original names
candidate_labels = list(intent_mapping.keys())
classifier(dataset["train"][0]["text"], candidate_labels)
# Out:
# {'sequence': 'i want to fly from boston at 838 am and arrive in denver at 1110 in the morning',
#  'labels': ['flight',
#   'airfare',
#   'distance',
#   'flight_time',
#   'restriction',
#   'aircraft',
#   'flight_no',
#   'abbreviation',
#   'airport',
#   'capacity',
#   'quantity',
#   'city',
#   'airline',
#   'ground_fare',
#   'ground_service+ground_fare',
#   'ground_service',
#   'meal',
#   'cheapest'],
#  'scores': [0.25311359763145447,
#   0.22531504929065704,
#   0.1666412353515625,
#   0.0520954392850399,
#   0.04511941224336624,
#   0.0373229943215847,
#   0.030164100229740143,
#   0.028714267536997795,
#   0.02366679161787033,
#   0.022193461656570435,
#   0.02065613493323326,
#   0.020584838464856148,
#   0.018283870071172714,
#   0.017191680148243904,
#   0.015278246253728867,
#   0.015065652318298817,
#   0.006112908013164997,
#   0.0024803695268929005]}

# %%
# use intent mapping names
candidate_labels = list(intent_mapping.values())
classifier(dataset["train"][0]["text"], candidate_labels)
# Out:
# {'sequence': 'i want to fly from boston at 838 am and arrive in denver at 1110 in the morning',
#  'labels': ['Flight Booking Request',
#   'Airport Distance Inquiry',
#   'Flight Schedule Inquiry',
#   'Airport Location Inquiry',
#   'Airfare Information Requests',
#   'Airport Information and Queries',
#   'Flight Number Inquiry',
#   'Airline Information Request',
#   'Ground Transportation Inquiry',
#   'Ground Transportation Cost Inquiry',
#   'Flight Quantity Inquiry',
#   'Aircraft Type Inquiry',
#   'Cheapest Fare Inquiry',
#   'Airport Ground Transportation and Cost Query',
#   'Flight Restriction Inquiry',
#   'Abbreviation and Fare Code Meaning Inquiry',
#   'Aircraft Seating Capacity Inquiry',
#   'Inquiry about In-flight Meals'],
#  'scores': [0.18264347314834595,
#   0.12421287596225739,
#   0.09362585097551346,
#   0.07969800382852554,
#   0.06246088445186615,
#   0.06208226457238197,
#   0.05942377820611,
#   0.05931268259882927,
#   0.04287651926279068,
#   0.042347412556409836,
#   0.03694706782698631,
#   0.03188294917345047,
#   0.0313902273774147,
#   0.025422459468245506,
#   0.02412569150328636,
#   0.01937163434922695,
#   0.0150524340569973,
#   0.007123837247490883]}

# %%
from tqdm import tqdm
results = []
for row in tqdm(dataset["test"]):
    intent = row["intent"] 
    if intent not in intent_mapping:
        continue 
    
    prediction = classifier(row["text"], candidate_labels)
    results.append({"prediction": prediction, "y": intent_mapping[intent]})
# Out:
#   1%|█▎                                                                                                                  | 10/893 [00:02<03:03,  4.80it/s]--- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_8248/1713124505.py", line 8, in <module>
#     prediction = classifier(row["text"], candidate_labels)
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/transformers/pipelines/zero_shot_classification.py", line 206, in __call__
#     return super().__call__(sequences, **kwargs)
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/transformers/pipelines/base.py", line 1167, in __call__
#     logger.warning_once(
#   File "/home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/transformers/utils/logging.py", line 329, in warning_once
#     self.warning(*args, **kwargs)
# Message: 'You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset'
# Arguments: (<class 'UserWarning'>,)
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 893/893 [02:52<00:00,  5.19it/s]

# %%
from sklearn.metrics import classification_report
y = [r["y"] for r in results]
predictions = [r["prediction"] for r in results]
predictions
# Out:
# [{'sequence': 'i would like to find a flight from charlotte to las vegas that makes a stop in st. louis',
#   'labels': ['Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Airport Location Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airport Information and Queries',
#    'Flight Number Inquiry',
#    'Flight Quantity Inquiry',
#    'Airfare Information Requests',
#    'Ground Transportation Cost Inquiry',
#    'Ground Transportation Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Cheapest Fare Inquiry',
#    'Aircraft Type Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.11526107788085938,
#    0.10899890959262848,
#    0.09994936734437943,
#    0.09034089744091034,
#    0.08156231790781021,
#    0.0749569907784462,
#    0.06290633231401443,
#    0.06271512806415558,
#    0.04818842187523842,
#    0.045033495873212814,
#    0.04165453836321831,
#    0.0386139415204525,
#    0.038605671375989914,
#    0.02378046326339245,
#    0.022838206961750984,
#    0.018985673785209656,
#    0.017498981207609177,
#    0.008109671995043755]},
#  {'sequence': 'on april first i need a ticket from tacoma to san jose departing before 7 am',
#   'labels': ['Flight Booking Request',
#    'Flight Schedule Inquiry',
#    'Airfare Information Requests',
#    'Airport Distance Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Airline Information Request',
#    'Ground Transportation Inquiry',
#    'Airport Location Inquiry',
#    'Airport Information and Queries',
#    'Flight Number Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Flight Restriction Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Flight Quantity Inquiry',
#    'Cheapest Fare Inquiry',
#    'Aircraft Type Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.20752419531345367,
#    0.09825783967971802,
#    0.08529933542013168,
#    0.08023114502429962,
#    0.06497881561517715,
#    0.06492837518453598,
#    0.06375117599964142,
#    0.06076045706868172,
#    0.04893936961889267,
#    0.047412578016519547,
#    0.046015895903110504,
#    0.03669320046901703,
#    0.03451564535498619,
#    0.022657647728919983,
#    0.014778371900320053,
#    0.009116992354393005,
#    0.008240006864070892,
#    0.005898956209421158]},
#  {'sequence': 'on april first i need a flight going from phoenix to san diego',
#   'labels': ['Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Airport Location Inquiry',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Airfare Information Requests',
#    'Ground Transportation Cost Inquiry',
#    'Airport Information and Queries',
#    'Flight Quantity Inquiry',
#    'Ground Transportation Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Type Inquiry',
#    'Flight Number Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Flight Restriction Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Cheapest Fare Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.13846634328365326,
#    0.12754948437213898,
#    0.09546130150556564,
#    0.08659602701663971,
#    0.08398990333080292,
#    0.06737137585878372,
#    0.06446477025747299,
#    0.05296389386057854,
#    0.04606983810663223,
#    0.045184582471847534,
#    0.039931781589984894,
#    0.03639381378889084,
#    0.03580056503415108,
#    0.02134900726377964,
#    0.019910477101802826,
#    0.019234558567404747,
#    0.013881112448871136,
#    0.005381146911531687]},
#  {'sequence': 'i would like a flight traveling one way from phoenix to san diego on april first',
#   'labels': ['Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Flight Schedule Inquiry',
#    'Flight Number Inquiry',
#    'Airline Information Request',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Flight Quantity Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Ground Transportation Inquiry',
#    'Airport Location Inquiry',
#    'Airfare Information Requests',
#    'Airport Information and Queries',
#    'Aircraft Type Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Cheapest Fare Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.14442718029022217,
#    0.12310505658388138,
#    0.09317579120397568,
#    0.07970933616161346,
#    0.07955748587846756,
#    0.0664503276348114,
#    0.061955712735652924,
#    0.05055965855717659,
#    0.04927385225892067,
#    0.04733734577894211,
#    0.04689548537135124,
#    0.03563062474131584,
#    0.027952034026384354,
#    0.02715226821601391,
#    0.025577474385499954,
#    0.020198604092001915,
#    0.016700223088264465,
#    0.0043415529653429985]},
#  {'sequence': 'i would like a flight from orlando to salt lake city for april first on delta airlines',
#   'labels': ['Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Airport Location Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Flight Number Inquiry',
#    'Flight Quantity Inquiry',
#    'Ground Transportation Inquiry',
#    'Airport Information and Queries',
#    'Ground Transportation Cost Inquiry',
#    'Airfare Information Requests',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Type Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Cheapest Fare Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.12698322534561157,
#    0.11753451079130173,
#    0.09521009027957916,
#    0.08721204102039337,
#    0.07387203723192215,
#    0.07225660234689713,
#    0.06757870316505432,
#    0.057440049946308136,
#    0.05134817585349083,
#    0.04597526043653488,
#    0.043261267244815826,
#    0.041969772428274155,
#    0.028953786939382553,
#    0.02321556955575943,
#    0.02166593447327614,
#    0.021464867517352104,
#    0.020453600212931633,
#    0.003604562021791935]},
#  {'sequence': 'i need a flight from toronto to newark one way leaving wednesday evening or thursday morning',
#   'labels': ['Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Airport Information and Queries',
#    'Airfare Information Requests',
#    'Airport Location Inquiry',
#    'Flight Quantity Inquiry',
#    'Flight Number Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Ground Transportation Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Flight Restriction Inquiry',
#    'Cheapest Fare Inquiry',
#    'Aircraft Type Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.155416339635849,
#    0.1245812252163887,
#    0.10189229995012283,
#    0.0847947895526886,
#    0.07320816814899445,
#    0.07261960208415985,
#    0.06912383437156677,
#    0.04663484916090965,
#    0.04298650100827217,
#    0.04113076627254486,
#    0.03530270978808403,
#    0.03160025551915169,
#    0.028776556253433228,
#    0.026618970558047295,
#    0.024745123460888863,
#    0.019509010016918182,
#    0.01480899564921856,
#    0.006250109523534775]},
#  {'sequence': 'monday morning i would like to fly from columbus to indianapolis',
#   'labels': ['Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Airport Location Inquiry',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Ground Transportation Cost Inquiry',
#    'Flight Number Inquiry',
#    'Airfare Information Requests',
#    'Ground Transportation Inquiry',
#    'Airport Information and Queries',
#    'Airport Ground Transportation and Cost Query',
#    'Flight Quantity Inquiry',
#    'Aircraft Type Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Cheapest Fare Inquiry',
#    'Flight Restriction Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.13458088040351868,
#    0.13406431674957275,
#    0.10556328296661377,
#    0.09680787473917007,
#    0.08316902071237564,
#    0.05946705490350723,
#    0.05616050213575363,
#    0.05378364399075508,
#    0.05136948823928833,
#    0.04492498189210892,
#    0.038374777883291245,
#    0.03550292178988457,
#    0.030657386407256126,
#    0.019844135269522667,
#    0.018962834030389786,
#    0.015573898330330849,
#    0.015373577363789082,
#    0.005819370038807392]},
#  {'sequence': 'on wednesday april sixth i would like to fly from long beach to columbus after 3 pm',
#   'labels': ['Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Flight Schedule Inquiry',
#    'Airport Location Inquiry',
#    'Airline Information Request',
#    'Flight Number Inquiry',
#    'Airfare Information Requests',
#    'Ground Transportation Inquiry',
#    'Airport Information and Queries',
#    'Ground Transportation Cost Inquiry',
#    'Flight Quantity Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Type Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Flight Restriction Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Cheapest Fare Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.15529899299144745,
#    0.12165098637342453,
#    0.10489879548549652,
#    0.08826243877410889,
#    0.07308221608400345,
#    0.0664285272359848,
#    0.051856618374586105,
#    0.0441698394715786,
#    0.04405413195490837,
#    0.04350830987095833,
#    0.039248064160346985,
#    0.036343447864055634,
#    0.0317811481654644,
#    0.024791670963168144,
#    0.023206405341625214,
#    0.02192888967692852,
#    0.021468861028552055,
#    0.008020634762942791]},
#  {'sequence': 'after 12 pm on wednesday april sixth i would like to fly from long beach to columbus',
#   'labels': ['Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Airport Location Inquiry',
#    'Flight Schedule Inquiry',
#    'Flight Number Inquiry',
#    'Airline Information Request',
#    'Ground Transportation Cost Inquiry',
#    'Ground Transportation Inquiry',
#    'Airfare Information Requests',
#    'Flight Quantity Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Airport Information and Queries',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Aircraft Type Inquiry',
#    'Cheapest Fare Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.15559515357017517,
#    0.13091184198856354,
#    0.09877539426088333,
#    0.08313228189945221,
#    0.06935498118400574,
#    0.06665784865617752,
#    0.05866556242108345,
#    0.05083567649126053,
#    0.043327510356903076,
#    0.041935235261917114,
#    0.03998921811580658,
#    0.03767836093902588,
#    0.029266618192195892,
#    0.029224595054984093,
#    0.02028876356780529,
#    0.020166274160146713,
#    0.01622348092496395,
#    0.00797122810035944]},
#  {'sequence': 'are there any flights from long beach to columbus on wednesday april sixth',
#   'labels': ['Flight Schedule Inquiry',
#    'Flight Booking Request',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airport Distance Inquiry',
#    'Airline Information Request',
#    'Ground Transportation Inquiry',
#    'Flight Number Inquiry',
#    'Flight Quantity Inquiry',
#    'Airport Information and Queries',
#    'Ground Transportation Cost Inquiry',
#    'Airport Location Inquiry',
#    'Flight Restriction Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Type Inquiry',
#    'Cheapest Fare Inquiry',
#    'Airfare Information Requests',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.12085627764463425,
#    0.09021736681461334,
#    0.08978410810232162,
#    0.08349540829658508,
#    0.07698772847652435,
#    0.07684609293937683,
#    0.07635753601789474,
#    0.059055302292108536,
#    0.05570819228887558,
#    0.04891955479979515,
#    0.04670049622654915,
#    0.03194572031497955,
#    0.02979087084531784,
#    0.028760390356183052,
#    0.028093690052628517,
#    0.02707902155816555,
#    0.01942499540746212,
#    0.009977279230952263]},
#  {'sequence': 'find a flight from memphis to tacoma dinner',
#   'labels': ['Inquiry about In-flight Meals',
#    'Airport Distance Inquiry',
#    'Airport Location Inquiry',
#    'Flight Booking Request',
#    'Flight Number Inquiry',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Ground Transportation Cost Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Ground Transportation Inquiry',
#    'Flight Quantity Inquiry',
#    'Airfare Information Requests',
#    'Airport Information and Queries',
#    'Cheapest Fare Inquiry',
#    'Aircraft Type Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Flight Restriction Inquiry',
#    'Aircraft Seating Capacity Inquiry'],
#   'scores': [0.13929635286331177,
#    0.12305325269699097,
#    0.09482526034116745,
#    0.0775277391076088,
#    0.06409553438425064,
#    0.058115553110837936,
#    0.05738784372806549,
#    0.053178489208221436,
#    0.04602609947323799,
#    0.044234052300453186,
#    0.040954578667879105,
#    0.04036535322666168,
#    0.03836364671587944,
#    0.03570885583758354,
#    0.032493140548467636,
#    0.029725724831223488,
#    0.0162937231361866,
#    0.008354724384844303]},
#  {'sequence': 'on next wednesday flight from kansas city to chicago should arrive in chicago around 7 pm return flight on thursday',
#   'labels': ['Flight Schedule Inquiry',
#    'Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Airline Information Request',
#    'Airport Location Inquiry',
#    'Airport Information and Queries',
#    'Ground Transportation Inquiry',
#    'Flight Number Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Type Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Flight Quantity Inquiry',
#    'Airfare Information Requests',
#    'Cheapest Fare Inquiry',
#    'Flight Restriction Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.09513074904680252,
#    0.09129936248064041,
#    0.08963210880756378,
#    0.07612477988004684,
#    0.07090818881988525,
#    0.06740052253007889,
#    0.06251496076583862,
#    0.05843643099069595,
#    0.056570228189229965,
#    0.0466926284134388,
#    0.046069975942373276,
#    0.044548261910676956,
#    0.04402927681803703,
#    0.0423804372549057,
#    0.038200654089450836,
#    0.02731466107070446,
#    0.02622557431459427,
#    0.016521284356713295]},
#  {'sequence': 'flight on american from miami to chicago arrive in chicago about 5 pm',
#   'labels': ['Airport Distance Inquiry',
#    'Airport Location Inquiry',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Airport Information and Queries',
#    'Ground Transportation Inquiry',
#    'Aircraft Type Inquiry',
#    'Flight Number Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Flight Booking Request',
#    'Flight Quantity Inquiry',
#    'Airfare Information Requests',
#    'Cheapest Fare Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.10999918729066849,
#    0.09463799744844437,
#    0.08924372494220734,
#    0.08583156764507294,
#    0.07219629734754562,
#    0.06862635910511017,
#    0.0647330954670906,
#    0.06324610114097595,
#    0.0576891228556633,
#    0.05547849088907242,
#    0.041837677359580994,
#    0.03771178424358368,
#    0.03630727902054787,
#    0.03239899501204491,
#    0.02979658544063568,
#    0.02379816770553589,
#    0.0213943924754858,
#    0.015073205344378948]},
#  {'sequence': 'find flights arriving new york city next saturday',
#   'labels': ['Flight Schedule Inquiry',
#    'Flight Booking Request',
#    'Airline Information Request',
#    'Airport Distance Inquiry',
#    'Airport Location Inquiry',
#    'Airport Information and Queries',
#    'Flight Number Inquiry',
#    'Flight Quantity Inquiry',
#    'Airfare Information Requests',
#    'Ground Transportation Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Cheapest Fare Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Flight Restriction Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Type Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.2299489974975586,
#    0.11246300488710403,
#    0.10737140476703644,
#    0.08749895542860031,
#    0.08328022062778473,
#    0.0605548731982708,
#    0.0554930754005909,
#    0.04449130967259407,
#    0.04421732574701309,
#    0.04099860414862633,
#    0.03782489150762558,
#    0.023428715765476227,
#    0.019215088337659836,
#    0.017523664981126785,
#    0.01391852367669344,
#    0.013526205904781818,
#    0.005235285498201847,
#    0.0030099088326096535]},
#  {'sequence': 'find nonstop flights from salt lake city to new york on saturday april ninth',
#   'labels': ['Flight Schedule Inquiry',
#    'Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Airline Information Request',
#    'Airport Location Inquiry',
#    'Airport Information and Queries',
#    'Airfare Information Requests',
#    'Flight Quantity Inquiry',
#    'Cheapest Fare Inquiry',
#    'Flight Number Inquiry',
#    'Ground Transportation Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Aircraft Type Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.16577258706092834,
#    0.1430526077747345,
#    0.1091056689620018,
#    0.10371612757444382,
#    0.07781894505023956,
#    0.04958007484674454,
#    0.0474429689347744,
#    0.04575319215655327,
#    0.043426238000392914,
#    0.04198918119072914,
#    0.0383731871843338,
#    0.035671986639499664,
#    0.026524825021624565,
#    0.02037065662443638,
#    0.015031534247100353,
#    0.014851167798042297,
#    0.013698039576411247,
#    0.00782100297510624]},
#  {'sequence': 'show flights from burbank to milwaukee for today',
#   'labels': ['Airport Distance Inquiry',
#    'Flight Booking Request',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Ground Transportation Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Airport Location Inquiry',
#    'Flight Number Inquiry',
#    'Flight Quantity Inquiry',
#    'Airfare Information Requests',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Airport Information and Queries',
#    'Cheapest Fare Inquiry',
#    'Aircraft Type Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.16753920912742615,
#    0.11732178181409836,
#    0.09517358988523483,
#    0.07934693992137909,
#    0.06986981630325317,
#    0.059224795550107956,
#    0.05841498449444771,
#    0.05355170741677284,
#    0.0507122203707695,
#    0.04434030503034592,
#    0.040943946689367294,
#    0.040658675134181976,
#    0.039620641618967056,
#    0.032943397760391235,
#    0.025251133367419243,
#    0.013563301414251328,
#    0.006641308777034283,
#    0.004882245324552059]},
#  {'sequence': 'show flights tomorrow evening from milwaukee to st. louis',
#   'labels': ['Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Flight Quantity Inquiry',
#    'Flight Number Inquiry',
#    'Airport Location Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Ground Transportation Inquiry',
#    'Airport Information and Queries',
#    'Airfare Information Requests',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Cheapest Fare Inquiry',
#    'Aircraft Type Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.13143183290958405,
#    0.12510594725608826,
#    0.09226669371128082,
#    0.08793050050735474,
#    0.08294551074504852,
#    0.06447743624448776,
#    0.05563880503177643,
#    0.052520476281642914,
#    0.049760397523641586,
#    0.04685704782605171,
#    0.04203943908214569,
#    0.04073323681950569,
#    0.03469497710466385,
#    0.02907426841557026,
#    0.02167068049311638,
#    0.019134333357214928,
#    0.01542419008910656,
#    0.008294242434203625]},
#  {'sequence': 'show flights saturday evening from st. louis to burbank',
#   'labels': ['Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Airline Information Request',
#    'Flight Schedule Inquiry',
#    'Flight Quantity Inquiry',
#    'Airport Information and Queries',
#    'Airport Location Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Flight Number Inquiry',
#    'Ground Transportation Inquiry',
#    'Airfare Information Requests',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Cheapest Fare Inquiry',
#    'Aircraft Type Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.12882773578166962,
#    0.12431596964597702,
#    0.09393006563186646,
#    0.09054768830537796,
#    0.07142003625631332,
#    0.057026010006666183,
#    0.05620811879634857,
#    0.05315518006682396,
#    0.05286985635757446,
#    0.049583882093429565,
#    0.04857175424695015,
#    0.03735324367880821,
#    0.03719198703765869,
#    0.029695235192775726,
#    0.024630343541502953,
#    0.020976630970835686,
#    0.012558328919112682,
#    0.011137919500470161]},
#  {'sequence': 'show flights from burbank to st. louis on monday',
#   'labels': ['Airport Distance Inquiry',
#    'Flight Booking Request',
#    'Airline Information Request',
#    'Flight Schedule Inquiry',
#    'Flight Number Inquiry',
#    'Airport Location Inquiry',
#    'Ground Transportation Inquiry',
#    'Flight Quantity Inquiry',
#    'Airport Information and Queries',
#    'Ground Transportation Cost Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Cheapest Fare Inquiry',
#    'Airfare Information Requests',
#    'Aircraft Type Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals',
#    'Flight Restriction Inquiry'],
#   'scores': [0.11875493079423904,
#    0.11248943954706192,
#    0.08975107967853546,
#    0.07457578182220459,
#    0.07049687206745148,
#    0.059464555233716965,
#    0.059335123747587204,
#    0.05905691534280777,
#    0.0584486685693264,
#    0.049833811819553375,
#    0.0475543737411499,
#    0.043520424515008926,
#    0.04310793802142143,
#    0.03616149723529816,
#    0.033148616552352905,
#    0.023673513904213905,
#    0.011080346070230007,
#    0.009546198882162571]},
#  {'sequence': 'show flights from burbank to milwaukee on monday',
#   'labels': ['Airport Distance Inquiry',
#    'Flight Booking Request',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Flight Number Inquiry',
#    'Ground Transportation Inquiry',
#    'Flight Quantity Inquiry',
#    'Airport Location Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airport Information and Queries',
#    'Airfare Information Requests',
#    'Airport Ground Transportation and Cost Query',
#    'Cheapest Fare Inquiry',
#    'Aircraft Type Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.1280381977558136,
#    0.10898775607347488,
#    0.09095078706741333,
#    0.0872974768280983,
#    0.06940370053052902,
#    0.0652318149805069,
#    0.06046738103032112,
#    0.05518389865756035,
#    0.05442259833216667,
#    0.05080204829573631,
#    0.04829997196793556,
#    0.03969810903072357,
#    0.03682352602481842,
#    0.03487466275691986,
#    0.03244756907224655,
#    0.019496170803904533,
#    0.009685846976935863,
#    0.00788844097405672]},
#  {'sequence': 'show flights tuesday evening from milwaukee to st. louis',
#   'labels': ['Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Airline Information Request',
#    'Flight Schedule Inquiry',
#    'Flight Number Inquiry',
#    'Flight Quantity Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Airport Information and Queries',
#    'Airport Location Inquiry',
#    'Ground Transportation Inquiry',
#    'Airfare Information Requests',
#    'Cheapest Fare Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Aircraft Type Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.12607625126838684,
#    0.11234322935342789,
#    0.09052208811044693,
#    0.08718766272068024,
#    0.07815346866846085,
#    0.07671840488910675,
#    0.057918112725019455,
#    0.055077165365219116,
#    0.05427068844437599,
#    0.0480956993997097,
#    0.04280533641576767,
#    0.03654014691710472,
#    0.0334850437939167,
#    0.0314812995493412,
#    0.023009005934000015,
#    0.020733477547764778,
#    0.015365243889391422,
#    0.010217692703008652]},
#  {'sequence': 'show flights wednesday evening from st. louis to burbank',
#   'labels': ['Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Airline Information Request',
#    'Flight Schedule Inquiry',
#    'Flight Quantity Inquiry',
#    'Airport Information and Queries',
#    'Flight Number Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Airfare Information Requests',
#    'Airport Location Inquiry',
#    'Ground Transportation Inquiry',
#    'Cheapest Fare Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Aircraft Type Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.12615273892879486,
#    0.11594963818788528,
#    0.09102971851825714,
#    0.09012610465288162,
#    0.07612057775259018,
#    0.06198987364768982,
#    0.05563085898756981,
#    0.05398654192686081,
#    0.05180872231721878,
#    0.049683358520269394,
#    0.04580174386501312,
#    0.03869771584868431,
#    0.03507094085216522,
#    0.03136637434363365,
#    0.025718316435813904,
#    0.022744866088032722,
#    0.015332724899053574,
#    0.01278917957097292]},
#  {'sequence': 'which flights travel from kansas city to los angeles',
#   'labels': ['Airport Distance Inquiry',
#    'Airport Location Inquiry',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Ground Transportation Inquiry',
#    'Airport Information and Queries',
#    'Ground Transportation Cost Inquiry',
#    'Flight Booking Request',
#    'Flight Quantity Inquiry',
#    'Flight Number Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Aircraft Type Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Airfare Information Requests',
#    'Cheapest Fare Inquiry',
#    'Flight Restriction Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.14517545700073242,
#    0.1269475668668747,
#    0.10458336025476456,
#    0.08673027157783508,
#    0.07395786792039871,
#    0.062120359390974045,
#    0.05965510755777359,
#    0.05161970853805542,
#    0.04963650554418564,
#    0.043297991156578064,
#    0.04234122857451439,
#    0.04163557291030884,
#    0.0279561597853899,
#    0.02739361859858036,
#    0.022696904838085175,
#    0.014956941828131676,
#    0.012461955659091473,
#    0.006833398714661598]},
#  {'sequence': 'what flights travel from las vegas to los angeles',
#   'labels': ['Airport Distance Inquiry',
#    'Airport Location Inquiry',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Ground Transportation Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airport Information and Queries',
#    'Flight Number Inquiry',
#    'Flight Quantity Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Type Inquiry',
#    'Airfare Information Requests',
#    'Flight Booking Request',
#    'Cheapest Fare Inquiry',
#    'Flight Restriction Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.15576496720314026,
#    0.12158945202827454,
#    0.0846031978726387,
#    0.0764240175485611,
#    0.07182343304157257,
#    0.0702228918671608,
#    0.06276244670152664,
#    0.06270202249288559,
#    0.061432745307683945,
#    0.057956449687480927,
#    0.032397810369729996,
#    0.032103050500154495,
#    0.0318962000310421,
#    0.03163502737879753,
#    0.01644442044198513,
#    0.012908539734780788,
#    0.010755560360848904,
#    0.0065777841955423355]},
#  {'sequence': 'which flights travel from kansas city to los angeles on april ninth',
#   'labels': ['Flight Schedule Inquiry',
#    'Airport Distance Inquiry',
#    'Airport Location Inquiry',
#    'Airline Information Request',
#    'Ground Transportation Inquiry',
#    'Flight Booking Request',
#    'Flight Quantity Inquiry',
#    'Airport Information and Queries',
#    'Ground Transportation Cost Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Flight Number Inquiry',
#    'Aircraft Type Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Airfare Information Requests',
#    'Cheapest Fare Inquiry',
#    'Flight Restriction Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.1648324728012085,
#    0.11399777233600616,
#    0.08391362428665161,
#    0.08186712861061096,
#    0.07004987448453903,
#    0.06363580375909805,
#    0.059064850211143494,
#    0.05750267207622528,
#    0.0534626804292202,
#    0.04922317713499069,
#    0.04624229297041893,
#    0.03592737764120102,
#    0.029514526948332787,
#    0.02391117624938488,
#    0.023224962875247,
#    0.02157720923423767,
#    0.013455466367304325,
#    0.008596964180469513]},
#  {'sequence': 'which flights travel from las vegas to los angeles california and arrive on april ninth between 4 and 5 pm',
#   'labels': ['Flight Schedule Inquiry',
#    'Airport Distance Inquiry',
#    'Airline Information Request',
#    'Airport Location Inquiry',
#    'Flight Number Inquiry',
#    'Airport Information and Queries',
#    'Ground Transportation Inquiry',
#    'Flight Booking Request',
#    'Flight Quantity Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Aircraft Type Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Cheapest Fare Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Airfare Information Requests',
#    'Flight Restriction Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.15103374421596527,
#    0.09583348035812378,
#    0.07981663942337036,
#    0.07705847173929214,
#    0.06931937485933304,
#    0.06699826568365097,
#    0.06368784606456757,
#    0.058226000517606735,
#    0.05518948659300804,
#    0.050475385040044785,
#    0.04526485875248909,
#    0.03633522242307663,
#    0.035113099962472916,
#    0.031117882579565048,
#    0.028916217386722565,
#    0.021265501156449318,
#    0.01880432479083538,
#    0.015544193796813488]},
#  {'sequence': 'which flights on us air go from orlando to cleveland',
#   'labels': ['Airport Location Inquiry',
#    'Airport Distance Inquiry',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Airport Information and Queries',
#    'Flight Quantity Inquiry',
#    'Aircraft Type Inquiry',
#    'Flight Number Inquiry',
#    'Flight Booking Request',
#    'Ground Transportation Cost Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Ground Transportation Inquiry',
#    'Airfare Information Requests',
#    'Airport Ground Transportation and Cost Query',
#    'Cheapest Fare Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.1991586983203888,
#    0.15265412628650665,
#    0.07829800993204117,
#    0.07766041159629822,
#    0.07641837000846863,
#    0.05009405314922333,
#    0.04528617858886719,
#    0.04463258013129234,
#    0.043011464178562164,
#    0.04295431450009346,
#    0.040171634405851364,
#    0.03638385236263275,
#    0.03336336836218834,
#    0.028098944574594498,
#    0.021326931193470955,
#    0.013787718489766121,
#    0.009525371715426445,
#    0.007173936348408461]},
#  {'sequence': 'which flights travel from cleveland to indianapolis on april fifth',
#   'labels': ['Flight Schedule Inquiry',
#    'Airport Location Inquiry',
#    'Airport Distance Inquiry',
#    'Flight Number Inquiry',
#    'Airline Information Request',
#    'Flight Quantity Inquiry',
#    'Ground Transportation Inquiry',
#    'Flight Booking Request',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airport Information and Queries',
#    'Ground Transportation Cost Inquiry',
#    'Aircraft Type Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Cheapest Fare Inquiry',
#    'Airfare Information Requests',
#    'Flight Restriction Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.1450398713350296,
#    0.09682024270296097,
#    0.09301452338695526,
#    0.08658640831708908,
#    0.07634015381336212,
#    0.06982407718896866,
#    0.06618242710828781,
#    0.062249407172203064,
#    0.06045188009738922,
#    0.04997628554701805,
#    0.04245920851826668,
#    0.032397765666246414,
#    0.027869287878274918,
#    0.02520509995520115,
#    0.02247767709195614,
#    0.02218806743621826,
#    0.013400394469499588,
#    0.007517232093960047]},
#  {'sequence': 'which flights travel from indianapolis to san diego on april fifth',
#   'labels': ['Flight Schedule Inquiry',
#    'Airport Distance Inquiry',
#    'Flight Number Inquiry',
#    'Airport Location Inquiry',
#    'Airline Information Request',
#    'Flight Booking Request',
#    'Flight Quantity Inquiry',
#    'Ground Transportation Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airport Information and Queries',
#    'Ground Transportation Cost Inquiry',
#    'Aircraft Type Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Airfare Information Requests',
#    'Cheapest Fare Inquiry',
#    'Flight Restriction Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.1604878306388855,
#    0.11028765887022018,
#    0.09690757840871811,
#    0.0894264429807663,
#    0.0747838169336319,
#    0.0647406280040741,
#    0.061837177723646164,
#    0.05625798925757408,
#    0.05469880998134613,
#    0.05286622792482376,
#    0.0406859889626503,
#    0.027392659336328506,
#    0.02575889602303505,
#    0.02358398400247097,
#    0.022188685834407806,
#    0.018944675102829933,
#    0.011630530469119549,
#    0.007520474027842283]},
#  {'sequence': 'which flights go from cleveland to indianapolis on april fifth',
#   'labels': ['Flight Schedule Inquiry',
#    'Airport Location Inquiry',
#    'Airport Distance Inquiry',
#    'Flight Number Inquiry',
#    'Airline Information Request',
#    'Ground Transportation Inquiry',
#    'Flight Quantity Inquiry',
#    'Flight Booking Request',
#    'Airport Information and Queries',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Aircraft Type Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Cheapest Fare Inquiry',
#    'Airfare Information Requests',
#    'Flight Restriction Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.149080291390419,
#    0.11397966742515564,
#    0.09912024438381195,
#    0.0785536915063858,
#    0.07374430447816849,
#    0.06826604902744293,
#    0.06305254250764847,
#    0.062448471784591675,
#    0.05242805927991867,
#    0.05031953006982803,
#    0.0385887436568737,
#    0.031202834099531174,
#    0.030227715149521828,
#    0.026827620342373848,
#    0.021068165078759193,
#    0.020185047760605812,
#    0.013590268790721893,
#    0.007316750939935446]},
#  {'sequence': 'which flights travel from nashville to tacoma',
#   'labels': ['Airport Distance Inquiry',
#    'Airport Location Inquiry',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Ground Transportation Inquiry',
#    'Flight Number Inquiry',
#    'Flight Booking Request',
#    'Airport Information and Queries',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Aircraft Type Inquiry',
#    'Flight Quantity Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Airfare Information Requests',
#    'Cheapest Fare Inquiry',
#    'Flight Restriction Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.1705402433872223,
#    0.14778782427310944,
#    0.10333343595266342,
#    0.08066998422145844,
#    0.06356117874383926,
#    0.060489900410175323,
#    0.05392048880457878,
#    0.05367458984255791,
#    0.05080433189868927,
#    0.044912248849868774,
#    0.04021042585372925,
#    0.038244735449552536,
#    0.028329594060778618,
#    0.023134253919124603,
#    0.01604449935257435,
#    0.010635866783559322,
#    0.009246911853551865,
#    0.00445942347869277]},
#  {'sequence': 'does tacoma airport offer transportation from the airport to the downtown area',
#   'labels': ['Airport Distance Inquiry',
#    'Ground Transportation Inquiry',
#    'Airport Location Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Ground Transportation Cost Inquiry',
#    'Airport Information and Queries',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Flight Number Inquiry',
#    'Cheapest Fare Inquiry',
#    'Aircraft Type Inquiry',
#    'Flight Quantity Inquiry',
#    'Airline Information Request',
#    'Flight Booking Request',
#    'Airfare Information Requests',
#    'Flight Schedule Inquiry',
#    'Flight Restriction Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.20234598219394684,
#    0.18618053197860718,
#    0.14720699191093445,
#    0.09271519631147385,
#    0.082433320581913,
#    0.06080042943358421,
#    0.049398429691791534,
#    0.027486557140946388,
#    0.02399047650396824,
#    0.023654360324144363,
#    0.0217550378292799,
#    0.019203566014766693,
#    0.012976976111531258,
#    0.011883554048836231,
#    0.011765720322728157,
#    0.009999614208936691,
#    0.00967717356979847,
#    0.006526029668748379]},
#  {'sequence': 'which flights travel from tacoma to san jose',
#   'labels': ['Airport Location Inquiry',
#    'Airport Distance Inquiry',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Ground Transportation Inquiry',
#    'Flight Number Inquiry',
#    'Airport Information and Queries',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Aircraft Type Inquiry',
#    'Flight Booking Request',
#    'Flight Quantity Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Airfare Information Requests',
#    'Cheapest Fare Inquiry',
#    'Flight Restriction Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.15528754889965057,
#    0.14386354386806488,
#    0.10336917638778687,
#    0.08360249549150467,
#    0.06816092878580093,
#    0.06519220769405365,
#    0.05567290261387825,
#    0.046528253704309464,
#    0.04533214867115021,
#    0.044889699667692184,
#    0.044015564024448395,
#    0.042433369904756546,
#    0.030060142278671265,
#    0.025392137467861176,
#    0.018273120746016502,
#    0.012255820445716381,
#    0.010450689122080803,
#    0.005220258608460426]},
#  {'sequence': 'what are the flights from tacoma to san jose',
#   'labels': ['Airline Information Request',
#    'Airport Distance Inquiry',
#    'Flight Schedule Inquiry',
#    'Airport Information and Queries',
#    'Airport Location Inquiry',
#    'Flight Number Inquiry',
#    'Flight Quantity Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Ground Transportation Inquiry',
#    'Flight Booking Request',
#    'Airport Ground Transportation and Cost Query',
#    'Airfare Information Requests',
#    'Aircraft Type Inquiry',
#    'Cheapest Fare Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.1145131066441536,
#    0.11334854364395142,
#    0.0964585468173027,
#    0.08728794753551483,
#    0.0871172845363617,
#    0.06258487701416016,
#    0.0616290420293808,
#    0.056100811809301376,
#    0.055734194815158844,
#    0.05045890063047409,
#    0.04763966053724289,
#    0.045003604143857956,
#    0.035471249371767044,
#    0.027621004730463028,
#    0.025068193674087524,
#    0.01376107893884182,
#    0.013230632990598679,
#    0.006971373222768307]},
#  {'sequence': 'what are the flights from tacoma to san jose',
#   'labels': ['Airline Information Request',
#    'Airport Distance Inquiry',
#    'Flight Schedule Inquiry',
#    'Airport Information and Queries',
#    'Airport Location Inquiry',
#    'Flight Number Inquiry',
#    'Flight Quantity Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Ground Transportation Inquiry',
#    'Flight Booking Request',
#    'Airport Ground Transportation and Cost Query',
#    'Airfare Information Requests',
#    'Aircraft Type Inquiry',
#    'Cheapest Fare Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.1145131066441536,
#    0.11334854364395142,
#    0.0964585468173027,
#    0.08728794753551483,
#    0.0871172845363617,
#    0.06258487701416016,
#    0.0616290420293808,
#    0.056100811809301376,
#    0.055734194815158844,
#    0.05045890063047409,
#    0.04763966053724289,
#    0.045003604143857956,
#    0.035471249371767044,
#    0.027621004730463028,
#    0.025068193674087524,
#    0.01376107893884182,
#    0.013230632990598679,
#    0.006971373222768307]},
#  {'sequence': 'i need a flight that goes from boston to orlando',
#   'labels': ['Airport Distance Inquiry',
#    'Airport Location Inquiry',
#    'Flight Booking Request',
#    'Airline Information Request',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airfare Information Requests',
#    'Airport Information and Queries',
#    'Ground Transportation Cost Inquiry',
#    'Flight Schedule Inquiry',
#    'Ground Transportation Inquiry',
#    'Flight Quantity Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Type Inquiry',
#    'Flight Number Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Cheapest Fare Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.13409201800823212,
#    0.1265466809272766,
#    0.09605424106121063,
#    0.088201142847538,
#    0.07752158492803574,
#    0.06749983876943588,
#    0.06115492433309555,
#    0.05660700798034668,
#    0.055420950055122375,
#    0.041223712265491486,
#    0.03919905424118042,
#    0.03435657173395157,
#    0.03282608464360237,
#    0.028254646807909012,
#    0.01978481374680996,
#    0.019120067358016968,
#    0.017569951713085175,
#    0.00456688366830349]},
#  {'sequence': 'are there any flights from boston to orlando connecting in new york',
#   'labels': ['Airport Distance Inquiry',
#    'Flight Booking Request',
#    'Flight Schedule Inquiry',
#    'Flight Number Inquiry',
#    'Airline Information Request',
#    'Airport Location Inquiry',
#    'Airport Information and Queries',
#    'Ground Transportation Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Flight Quantity Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Airfare Information Requests',
#    'Cheapest Fare Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Flight Restriction Inquiry',
#    'Aircraft Type Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.11498617380857468,
#    0.1049632728099823,
#    0.10366246849298477,
#    0.0889231339097023,
#    0.08841463923454285,
#    0.07531073689460754,
#    0.06952852755784988,
#    0.06865297257900238,
#    0.06728875637054443,
#    0.06703372299671173,
#    0.03192302584648132,
#    0.024742498993873596,
#    0.02394120581448078,
#    0.02192940004169941,
#    0.01804960146546364,
#    0.016070732846856117,
#    0.010020620189607143,
#    0.00455850875005126]},
#  {'sequence': 'are there any flights from boston to orlando connecting in columbus',
#   'labels': ['Airport Distance Inquiry',
#    'Flight Booking Request',
#    'Flight Schedule Inquiry',
#    'Ground Transportation Inquiry',
#    'Airline Information Request',
#    'Flight Number Inquiry',
#    'Airport Location Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airport Information and Queries',
#    'Flight Quantity Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Airfare Information Requests',
#    'Airport Ground Transportation and Cost Query',
#    'Cheapest Fare Inquiry',
#    'Flight Restriction Inquiry',
#    'Aircraft Type Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.11473406106233597,
#    0.0930112674832344,
#    0.09032659977674484,
#    0.08727891743183136,
#    0.08444246649742126,
#    0.0830218568444252,
#    0.08110790699720383,
#    0.06938999891281128,
#    0.06873928010463715,
#    0.0630231499671936,
#    0.037195924669504166,
#    0.027246858924627304,
#    0.024529332295060158,
#    0.022681979462504387,
#    0.01879057101905346,
#    0.018543047830462456,
#    0.011087208054959774,
#    0.004849558230489492]},
#  {'sequence': 'does this flight serve dinner',
#   'labels': ['Inquiry about In-flight Meals',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airline Information Request',
#    'Ground Transportation Inquiry',
#    'Flight Number Inquiry',
#    'Aircraft Type Inquiry',
#    'Airport Information and Queries',
#    'Flight Schedule Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Flight Quantity Inquiry',
#    'Airport Distance Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Cheapest Fare Inquiry',
#    'Flight Booking Request',
#    'Airport Location Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Airfare Information Requests'],
#   'scores': [0.5113071203231812,
#    0.06995857506990433,
#    0.047884274274110794,
#    0.038571134209632874,
#    0.03803567960858345,
#    0.03492587059736252,
#    0.03136385977268219,
#    0.03040393441915512,
#    0.028068268671631813,
#    0.027680691331624985,
#    0.02624852955341339,
#    0.02521190233528614,
#    0.022366032004356384,
#    0.02033132314682007,
#    0.018690042197704315,
#    0.011099678464233875,
#    0.008999408222734928,
#    0.008853601291775703]},
#  {'sequence': 'i need a flight from charlotte to miami',
#   'labels': ['Airport Distance Inquiry',
#    'Airport Location Inquiry',
#    'Flight Booking Request',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airline Information Request',
#    'Flight Schedule Inquiry',
#    'Airfare Information Requests',
#    'Ground Transportation Cost Inquiry',
#    'Airport Information and Queries',
#    'Flight Quantity Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Flight Number Inquiry',
#    'Ground Transportation Inquiry',
#    'Aircraft Type Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Cheapest Fare Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.14757604897022247,
#    0.12575989961624146,
#    0.10186833888292313,
#    0.07718799263238907,
#    0.07370887696743011,
#    0.06313993036746979,
#    0.06196005642414093,
#    0.05278845503926277,
#    0.05147787183523178,
#    0.046985164284706116,
#    0.044266436249017715,
#    0.03617619350552559,
#    0.03233866021037102,
#    0.031877242028713226,
#    0.018493564799427986,
#    0.015012922696769238,
#    0.014868449419736862,
#    0.004513840191066265]},
#  {'sequence': 'i need a nonstop flight from miami to toronto',
#   'labels': ['Airport Distance Inquiry',
#    'Airport Location Inquiry',
#    'Flight Booking Request',
#    'Airline Information Request',
#    'Airfare Information Requests',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Flight Schedule Inquiry',
#    'Airport Information and Queries',
#    'Ground Transportation Cost Inquiry',
#    'Flight Quantity Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Type Inquiry',
#    'Ground Transportation Inquiry',
#    'Cheapest Fare Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Number Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.14169961214065552,
#    0.11912251263856888,
#    0.11390243470668793,
#    0.08545863628387451,
#    0.07784709334373474,
#    0.07029931992292404,
#    0.06766529381275177,
#    0.05390886589884758,
#    0.04461820423603058,
#    0.03701648861169815,
#    0.03611484542489052,
#    0.03113810159265995,
#    0.030850442126393318,
#    0.02592405676841736,
#    0.02281588315963745,
#    0.019857240840792656,
#    0.0167093463242054,
#    0.005051491316407919]},
#  {'sequence': 'i need a nonstop flight from toronto to st. louis',
# ...
#    'Cheapest Fare Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Type Inquiry',
#    'Flight Restriction Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.1205110102891922,
#    0.11129892617464066,
#    0.09939644485712051,
#    0.09745338559150696,
#    0.0890270248055458,
#    0.07985596358776093,
#    0.06969799101352692,
#    0.05818517133593559,
#    0.04930488392710686,
#    0.048357754945755005,
#    0.040042806416749954,
#    0.0386803075671196,
#    0.02312662824988365,
#    0.022574270144104958,
#    0.01873183064162731,
#    0.017387861385941505,
#    0.012456663884222507,
#    0.003911046776920557]},
#  {'sequence': 'now show me all the flights from st. louis to burbank',
#   'labels': ['Airport Location Inquiry',
#    'Airport Distance Inquiry',
#    'Airline Information Request',
#    'Ground Transportation Cost Inquiry',
#    'Ground Transportation Inquiry',
#    'Flight Quantity Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Flight Schedule Inquiry',
#    'Airport Information and Queries',
#    'Aircraft Type Inquiry',
#    'Flight Booking Request',
#    'Airport Ground Transportation and Cost Query',
#    'Airfare Information Requests',
#    'Flight Number Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Cheapest Fare Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.14379450678825378,
#    0.1349063217639923,
#    0.08435731381177902,
#    0.07232386618852615,
#    0.06528648734092712,
#    0.06514133512973785,
#    0.0595400333404541,
#    0.05899455398321152,
#    0.05625779926776886,
#    0.043955616652965546,
#    0.04311586171388626,
#    0.04179787635803223,
#    0.03740560635924339,
#    0.02554687298834324,
#    0.023877402767539024,
#    0.019723612815141678,
#    0.017565719783306122,
#    0.006409205496311188]},
#  {'sequence': 'is there one airline that flies from burbank to milwaukee milwaukee to st. louis and from st. louis to burbank',
#   'labels': ['Airport Distance Inquiry',
#    'Flight Number Inquiry',
#    'Airline Information Request',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airport Location Inquiry',
#    'Flight Schedule Inquiry',
#    'Ground Transportation Inquiry',
#    'Airport Information and Queries',
#    'Aircraft Type Inquiry',
#    'Flight Quantity Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Flight Booking Request',
#    'Airport Ground Transportation and Cost Query',
#    'Cheapest Fare Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Airfare Information Requests',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.13681073486804962,
#    0.11180859804153442,
#    0.09134189784526825,
#    0.08444295078516006,
#    0.0745105892419815,
#    0.07012326270341873,
#    0.06512138992547989,
#    0.06285879015922546,
#    0.05639037489891052,
#    0.05032390356063843,
#    0.04332422837615013,
#    0.03266745060682297,
#    0.028733951970934868,
#    0.023674622178077698,
#    0.02115609683096409,
#    0.01910603977739811,
#    0.016762759536504745,
#    0.010842363350093365]},
#  {'sequence': 'find me all the round trip flights from burbank to milwaukee stopping in st. louis',
#   'labels': ['Airport Distance Inquiry',
#    'Flight Booking Request',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Airport Location Inquiry',
#    'Airfare Information Requests',
#    'Flight Quantity Inquiry',
#    'Airport Information and Queries',
#    'Ground Transportation Cost Inquiry',
#    'Ground Transportation Inquiry',
#    'Flight Number Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Cheapest Fare Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Type Inquiry',
#    'Flight Restriction Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.14063651859760284,
#    0.13811221718788147,
#    0.11459487676620483,
#    0.1065269336104393,
#    0.0882112979888916,
#    0.06861259788274765,
#    0.048645760864019394,
#    0.047370053827762604,
#    0.04534343630075455,
#    0.04282645508646965,
#    0.03901825100183487,
#    0.026432525366544724,
#    0.024358192458748817,
#    0.021610746160149574,
#    0.018098970875144005,
#    0.01207124162465334,
#    0.011742804199457169,
#    0.005787073168903589]},
#  {'sequence': "i 'd like to book two flights to westchester county",
#   'labels': ['Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Airport Location Inquiry',
#    'Flight Quantity Inquiry',
#    'Airline Information Request',
#    'Ground Transportation Cost Inquiry',
#    'Flight Schedule Inquiry',
#    'Airfare Information Requests',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Ground Transportation Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Airport Information and Queries',
#    'Cheapest Fare Inquiry',
#    'Flight Number Inquiry',
#    'Aircraft Type Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.19077429175376892,
#    0.10373328626155853,
#    0.08697537332773209,
#    0.06906252354383469,
#    0.06646095961332321,
#    0.06509648263454437,
#    0.06354976445436478,
#    0.056081175804138184,
#    0.05400851368904114,
#    0.049186743795871735,
#    0.045346204191446304,
#    0.041521064937114716,
#    0.026970624923706055,
#    0.026340197771787643,
#    0.019081857055425644,
#    0.016657527536153793,
#    0.013550651259720325,
#    0.005602837074548006]},
#  {'sequence': 'i want to book a flight from salt lake city to westchester county',
#   'labels': ['Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Airport Location Inquiry',
#    'Ground Transportation Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airfare Information Requests',
#    'Flight Number Inquiry',
#    'Airport Information and Queries',
#    'Flight Quantity Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Flight Restriction Inquiry',
#    'Cheapest Fare Inquiry',
#    'Aircraft Type Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.15198864042758942,
#    0.12564489245414734,
#    0.11586199700832367,
#    0.0625593364238739,
#    0.061326272785663605,
#    0.05938282608985901,
#    0.058334335684776306,
#    0.054807376116514206,
#    0.051440708339214325,
#    0.04950883239507675,
#    0.04708278924226761,
#    0.04465648531913757,
#    0.038136351853609085,
#    0.021582193672657013,
#    0.021262941882014275,
#    0.01739589124917984,
#    0.014456742443144321,
#    0.004571420606225729]},
#  {'sequence': 'tell me all the airports near westchester county',
#   'labels': ['Airport Location Inquiry',
#    'Airline Information Request',
#    'Airport Distance Inquiry',
#    'Ground Transportation Inquiry',
#    'Airport Information and Queries',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Airfare Information Requests',
#    'Flight Booking Request',
#    'Flight Number Inquiry',
#    'Flight Quantity Inquiry',
#    'Aircraft Type Inquiry',
#    'Flight Schedule Inquiry',
#    'Flight Restriction Inquiry',
#    'Cheapest Fare Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.2172556072473526,
#    0.1245693564414978,
#    0.11505734920501709,
#    0.10397219657897949,
#    0.07293305546045303,
#    0.06787963211536407,
#    0.0581388995051384,
#    0.05087662115693092,
#    0.032363083213567734,
#    0.02727695181965828,
#    0.022987933829426765,
#    0.02296336181461811,
#    0.022661689668893814,
#    0.019763192161917686,
#    0.013972192071378231,
#    0.012663353234529495,
#    0.010460194200277328,
#    0.004205301403999329]},
#  {'sequence': "i 'd like to book a flight from cincinnati to new york city on united airlines for next saturday",
#   'labels': ['Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Flight Number Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airport Location Inquiry',
#    'Airport Information and Queries',
#    'Ground Transportation Cost Inquiry',
#    'Flight Quantity Inquiry',
#    'Airfare Information Requests',
#    'Airport Ground Transportation and Cost Query',
#    'Ground Transportation Inquiry',
#    'Cheapest Fare Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Aircraft Type Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.2373533993959427,
#    0.09757162630558014,
#    0.09565192461013794,
#    0.07493501901626587,
#    0.06936198472976685,
#    0.056028496474027634,
#    0.051687125116586685,
#    0.04772690683603287,
#    0.043587371706962585,
#    0.041587945073843,
#    0.04074105620384216,
#    0.031021134927868843,
#    0.029954949393868446,
#    0.02340281382203102,
#    0.019556699320673943,
#    0.019467061385512352,
#    0.017039306461811066,
#    0.0033251552376896143]},
#  {'sequence': 'tell me all the airports in the new york city area',
#   'labels': ['Airport Location Inquiry',
#    'Ground Transportation Inquiry',
#    'Airport Distance Inquiry',
#    'Airline Information Request',
#    'Ground Transportation Cost Inquiry',
#    'Airport Information and Queries',
#    'Airport Ground Transportation and Cost Query',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Flight Quantity Inquiry',
#    'Flight Booking Request',
#    'Airfare Information Requests',
#    'Aircraft Type Inquiry',
#    'Flight Number Inquiry',
#    'Flight Schedule Inquiry',
#    'Flight Restriction Inquiry',
#    'Cheapest Fare Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.196668803691864,
#    0.1294756531715393,
#    0.12165044993162155,
#    0.11416957527399063,
#    0.0674906075000763,
#    0.0652552917599678,
#    0.048466794192790985,
#    0.04689275845885277,
#    0.03323686495423317,
#    0.033128347247838974,
#    0.029601190239191055,
#    0.024062639102339745,
#    0.023650038987398148,
#    0.02353253960609436,
#    0.015076562762260437,
#    0.013124029152095318,
#    0.01084891241043806,
#    0.0036689252592623234]},
#  {'sequence': 'please find all the flights from cincinnati to any airport in the new york city area that arrive next saturday before 6 pm',
#   'labels': ['Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Flight Booking Request',
#    'Airport Location Inquiry',
#    'Airport Information and Queries',
#    'Flight Quantity Inquiry',
#    'Ground Transportation Inquiry',
#    'Airport Distance Inquiry',
#    'Airfare Information Requests',
#    'Flight Number Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Flight Restriction Inquiry',
#    'Aircraft Type Inquiry',
#    'Cheapest Fare Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.1431332677602768,
#    0.1302877813577652,
#    0.10334714502096176,
#    0.09256945550441742,
#    0.0876057967543602,
#    0.05824771523475647,
#    0.058000337332487106,
#    0.05732422694563866,
#    0.04999198764562607,
#    0.043024469166994095,
#    0.03677307441830635,
#    0.03661981225013733,
#    0.026167649775743484,
#    0.022471891716122627,
#    0.022084331139922142,
#    0.015263141132891178,
#    0.010712540708482265,
#    0.006375296041369438]},
#  {'sequence': 'find me a flight from cincinnati to any airport in the new york city area',
#   'labels': ['Flight Booking Request',
#    'Airport Location Inquiry',
#    'Airport Distance Inquiry',
#    'Flight Schedule Inquiry',
#    'Airline Information Request',
#    'Ground Transportation Inquiry',
#    'Airfare Information Requests',
#    'Flight Number Inquiry',
#    'Flight Quantity Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airport Information and Queries',
#    'Airport Ground Transportation and Cost Query',
#    'Cheapest Fare Inquiry',
#    'Flight Restriction Inquiry',
#    'Aircraft Type Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.14589519798755646,
#    0.1220305785536766,
#    0.11583305895328522,
#    0.08345621824264526,
#    0.07396458089351654,
#    0.06514471024274826,
#    0.05124819278717041,
#    0.05022327974438667,
#    0.050075288861989975,
#    0.048801399767398834,
#    0.04865334928035736,
#    0.044020891189575195,
#    0.034937210381031036,
#    0.02163289487361908,
#    0.02042454667389393,
#    0.01267160288989544,
#    0.007047557737678289,
#    0.003939440473914146]},
#  {'sequence': "i 'd like to fly from miami to chicago on american airlines",
#   'labels': ['Airport Distance Inquiry',
#    'Flight Booking Request',
#    'Airport Location Inquiry',
#    'Airline Information Request',
#    'Flight Schedule Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Ground Transportation Inquiry',
#    'Flight Quantity Inquiry',
#    'Airfare Information Requests',
#    'Airport Information and Queries',
#    'Flight Number Inquiry',
#    'Aircraft Type Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Seating Capacity Inquiry',
#    'Cheapest Fare Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.13495735824108124,
#    0.12062712758779526,
#    0.0905328243970871,
#    0.08985495567321777,
#    0.07413554191589355,
#    0.05922897532582283,
#    0.058049000799655914,
#    0.05042567476630211,
#    0.049467891454696655,
#    0.04861418530344963,
#    0.044563282281160355,
#    0.039800431579351425,
#    0.039424650371074677,
#    0.031021174043416977,
#    0.02691328339278698,
#    0.02091010846197605,
#    0.014950397424399853,
#    0.006523184012621641]},
#  {'sequence': 'i would like to book a round trip flight from kansas city to chicago',
#   'labels': ['Flight Booking Request',
#    'Airport Distance Inquiry',
#    'Airport Location Inquiry',
#    'Airline Information Request',
#    'Flight Schedule Inquiry',
#    'Flight Quantity Inquiry',
#    'Ground Transportation Cost Inquiry',
#    'Flight Number Inquiry',
#    'Airfare Information Requests',
#    'Ground Transportation Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airport Information and Queries',
#    'Airport Ground Transportation and Cost Query',
#    'Aircraft Seating Capacity Inquiry',
#    'Cheapest Fare Inquiry',
#    'Aircraft Type Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.1651717871427536,
#    0.12495865672826767,
#    0.07732430100440979,
#    0.07111940532922745,
#    0.06906336545944214,
#    0.06409952044487,
#    0.0566738024353981,
#    0.0556461326777935,
#    0.052004776895046234,
#    0.050542932003736496,
#    0.048392314463853836,
#    0.0445144958794117,
#    0.03881077840924263,
#    0.021561063826084137,
#    0.020896604284644127,
#    0.018457120284438133,
#    0.01573825627565384,
#    0.005024744663387537]},
#  {'sequence': 'find me a flight that flies from memphis to tacoma',
#   'labels': ['Airport Distance Inquiry',
#    'Abbreviation and Fare Code Meaning Inquiry',
#    'Airport Location Inquiry',
#    'Flight Booking Request',
#    'Airline Information Request',
#    'Ground Transportation Cost Inquiry',
#    'Aircraft Type Inquiry',
#    'Flight Schedule Inquiry',
#    'Airfare Information Requests',
#    'Flight Quantity Inquiry',
#    'Airport Information and Queries',
#    'Flight Number Inquiry',
#    'Ground Transportation Inquiry',
#    'Airport Ground Transportation and Cost Query',
#    'Cheapest Fare Inquiry',
#    'Aircraft Seating Capacity Inquiry',
#    'Flight Restriction Inquiry',
#    'Inquiry about In-flight Meals'],
#   'scores': [0.11479330062866211,
#    0.10900786519050598,
#    0.10447119921445847,
#    0.08715905249118805,
#    0.07572057843208313,
#    0.057823821902275085,
#    0.05326206237077713,
#    0.05320057272911072,
#    0.05313311889767647,
#    0.052688438445329666,
#    0.05047767981886864,
#    0.04726952314376831,
#    0.04722251370549202,
#    0.035810019820928574,
#    0.02312849834561348,
#    0.017026083543896675,
#    0.013222256675362587,
#    0.004583451431244612]}]

# %%
prediction_labels = []
for row in predictions:
    max_index = row['scores'].index(max(row['scores']))
    label = row['labels'][max_index]
    prediction_labels.append(label)
print(len(prediction_labels))
# Out:
# 876

# %%
pd.DataFrame(classification_report(y, prediction_labels, output_dict=True)).T
# Out:
# /home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/serj/dev/customer_support_classifier/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                             precision    recall  f1-score  \
# Abbreviation and Fare Code Meaning Inquiry   0.482143  0.818182  0.606742
# Aircraft Seating Capacity Inquiry            1.000000  0.952381  0.975610
# Aircraft Type Inquiry                        0.600000  1.000000  0.750000
# Airfare Information Requests                 0.500000  0.020833  0.040000
# Airline Information Request                  0.064516  0.105263  0.080000
# Airport Distance Inquiry                     0.024823  0.700000  0.047945
# Airport Information and Queries              0.000000  0.000000  0.000000
# Airport Location Inquiry                     0.000000  0.000000  0.000000
# Cheapest Fare Inquiry                        0.000000  0.000000  0.000000
# Flight Booking Request                       0.943820  0.265823  0.414815
# Flight Number Inquiry                        0.727273  1.000000  0.842105
# Flight Quantity Inquiry                      0.066667  0.666667  0.121212
# Flight Schedule Inquiry                      0.016393  1.000000  0.032258
# Ground Transportation Cost Inquiry           0.133333  0.285714  0.181818
# Ground Transportation Inquiry                0.820513  0.888889  0.853333
# Inquiry about In-flight Meals                0.230769  1.000000  0.375000
# accuracy                                     0.327626  0.327626  0.327626
# macro avg                                    0.350641  0.543984  0.332552
# weighted avg                                 0.802963  0.327626  0.406665
#
#                                                support
# Abbreviation and Fare Code Meaning Inquiry   33.000000
# Aircraft Seating Capacity Inquiry            21.000000
# Aircraft Type Inquiry                         9.000000
# Airfare Information Requests                 48.000000
# Airline Information Request                  38.000000
# Airport Distance Inquiry                     10.000000
# Airport Information and Queries              18.000000
# Airport Location Inquiry                      6.000000
# Cheapest Fare Inquiry                         0.000000
# Flight Booking Request                      632.000000
# Flight Number Inquiry                         8.000000
# Flight Quantity Inquiry                       3.000000
# Flight Schedule Inquiry                       1.000000
# Ground Transportation Cost Inquiry            7.000000
# Ground Transportation Inquiry                36.000000
# Inquiry about In-flight Meals                 6.000000
# accuracy                                      0.327626
# macro avg                                   876.000000
# weighted avg                                876.000000
